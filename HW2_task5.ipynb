# %%
import matplotlib.pyplot as plt
import json

# %% [markdown]
# # Step One: Call the random_number.py

# %% [markdown]
# This process will generate a json file which contain a list with 1000 random number between 0 and 100.

# %%
# %run random_number.py

# %% [markdown]
# 1. The procession of the initial graph

# %% [markdown]
# 1.1 get the data from the file which generated by random_number.py

# %%
with open('file1.json', 'r') as f:
        num_list = json.loads(f.read())

# %% [markdown]
# 1.2 generate the data distribution bar graph from the data

# %%
plt.hist(num_list, bins=20, normed=0, facecolor="blue", edgecolor="black", alpha=0.7)
plt.xlabel("range")
plt.ylabel("count")
plt.title("data distribution bar graph")
plt.show()
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # Step Two: Call the function.py

# %% [markdown]
# This process will base on the result of first file and the formula y = 3 * x + 6 to generate 1000 new number and storing them into a list; then, putting the list into a json file. The value of y will be in a range from 6 to 306.

# %%
# %run function.py

# %% [markdown]
# 2. The procession of the intermidiate graph

# %% [markdown]
# 2.1 get the data from the file which generated by function.py

# %%
with open('file2.json', 'r') as f:
        num_list2 = json.loads(f.read())
        
count_num = [0, 0, 0, 0, 0, 0]

for i in num_list2:
    if 6<= i <= 56:
        count_num[0] += 1
    elif 57<= i <= 106:
        count_num[1] += 1
    elif 107<= i <= 156:
        count_num[2] += 1
    elif 157<= i <= 206:
        count_num[3] += 1
    elif 207<= i <= 256:
        count_num[4] += 1
    else:
        count_num[5] += 1

# %% [markdown]
# 2.2 generate the data distribution sector graph from the data

# %%
plt.figure(figsize=(9,9))
labels = [f'[6,56]',f'[57,106]',f'[107,156]',f'[157,206]',f'[207,256]',f'[257,306]'] 
colors = ['red','yellowgreen','lightskyblue','yellow','blue','green'] # define the colors
explode = (0,0,0,0,0,0) 
patches,text1,text2 = plt.pie(count_num, explode=explode,labels=labels,colors=colors,autopct = '%.2f%%',shadow = False,startangle =75, pctdistance = .6) 
plt.title("data distribution sector graph")
plt.axis('equal')
plt.show()

# %% [markdown]
# # Step Three: Call the visualization.py

# %% [markdown]
# This process will create a graph using the data which generated from step one and step two, and store the graph as jpg file.

# %%
# %run visualization.py

# %% [markdown]
# 3. The procession of the final results

# %% [markdown]
# 3.1 get the data from the files which generated by random_number.py and function.py

# %%
with open('file1.json', 'r') as f:
    x = json.loads(f.read())
with open('file2.json', 'r') as f:
    y = json.loads(f.read())

# %% [markdown]
# 3.2 generate the linear graph from the data

# %%
fig, ax = plt.subplots()
ax.plot(x, y)
plt.xlabel("random number range from [0,100]")
plt.ylabel("fomula result range from [6,306]")
plt.title("linear graph")
plt.show()
